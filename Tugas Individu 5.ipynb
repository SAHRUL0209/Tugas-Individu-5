# %%
class MyClass:
    x = 5

# %%
print(MyClass)
# Out:
# <class '__main__.MyClass'>

# %%
print(dir(MyClass))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'x']

# %%
class MyClass:
    x = 5
    y = 'hello world'

myObj = MyClass()

# %%
type(myObj)
# Out:
# __main__.MyClass

# %%
print(myObj.x)
# Out:
# 5

# %%
print(myObj.y)
# Out:
# hello world

# %%
class Person:
    def __init__(self, name, age):
        self.name = name  # assign value ke properties pada object
        self.age = age    # assign value ke properties pada object

# %%
person1 = Person("John", 36)

# %%
print(person1.name)
print(person1.age)
# Out:
# John
# 36

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def myfunc(self):
        print("Hello my name is " + self.name)

# %%
class Person:
    def __init__(self, name, age, A, B):
        self.name = name
        self.age = age
        self.A = A
        self.B = B

    def myfunc(self):
        print("Hello my name is " + self.name)
        print("and my age is %d" % self.age)
    
    def hitung(self):
        print ("%d + %d = %d" % (self.A, self.B, self.A + self.B))

# %%
# buat object `person1`
person1 = Person("John", 36, 12, 67)

# %%
print(dir(person1))
# Out:
# ['A', 'B', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'age', 'hitung', 'myfunc', 'name']

# %%
# access method pada object `person1`
person1.myfunc()
# Out:
# Hello my name is John
# and my age is 36

# %%
person1.hitung()
# Out:
# 12 + 67 = 79

# %%
class Person:
    def __init__(myInternalObj, name, age):
        myInternalObj.name = name
        myInternalObj.age = age

    def myfunc(myInternalObj):
        print("Hello my name is " + myInternalObj.name)
        
    def hitung(myInternalObj):
        print("test", myInternalObj.name)

# %%
# buat object `person1`
person1 = Person("John", 36)

# %%
# access method pada object `person1`
person1.hitung()
# Out:
# test John

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def myfunc():
        print("Hello my name is " + self.name)
        print("and my age is %d" % self.age)

# %%
person1 = Person("John", 36)

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def myfunc(self):
        print("Hello my name is " + self.name)

# %%
person1 = Person("John", 36)

# %%
person1.age
# Out:
# 36

# %%
person1.age = 40

print(person1.age)
# Out:
# 40

# %%
type(person1.age)
# Out:
# int

# %%
person1.age = '40'

# %%
type(person1.age)
# Out:
# str

# %%
print(dir(person1))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'age', 'myfunc', 'name']

# %%
del person1.age

# %%
print(dir(person1))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'myfunc', 'name']

# %%
del person1

# %%
class Person:
    pass

# %%
person1 = Person()

# %%
dir(person1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
class Person:
    def __init__(self, fname, lname):
        self.firstname = fname
        self.lastname = lname

    def printname(self):
        print(self.firstname, self.lastname)

# %%
x = Person("Budi", "Darmawan")
x.printname()
# Out:
# Budi Darmawan

# %%
class Student(Person):
    pass # lakukan pass jika tidak ingin menambahkan apapun pada child class `Student`

# %%
x = Student("Budi", "Darmawan")
x.printname()
# Out:
# Budi Darmawan

# %%
print(dir(Student))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'printname']

# %%
print(dir(Person))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'printname']

# %%
class Student(Person):
    def __init__(self, fname, lname):
        self.new_var = fname + " - " + lname

# %%
x = Student("John", "Doe")

# %%
class Student(Person):
    def __init__(self, fname, lname):
        self.new_var = fname + " - " + lname
        Person.__init__(self, fname, lname)

# %%
x = Student("John", "Doe")

# %%
x.printname()
# Out:
# John Doe

# %%
print(dir(x))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'firstname', 'lastname', 'new_var', 'printname']

# %%
x.new_var
# Out:
# 'John - Doe'

# %%
class Person:
    def __init__(self, fname, lname):
        self.firstname = fname
        self.lastname = lname

    def printname(self):
        print(self.firstname, self.lastname)

class Student(Person):
    def __init__(self, fname, lname):
        self.new_var = fname + " - " + lname
        super().__init__(fname, lname)

# %%
x = Student("Budi", "Darmawan")
x.printname()
# Out:
# Budi Darmawan

# %%
class Student(Person):
    def __init__(self, fname, lname, year):
        super().__init__(fname, lname)
        self.graduationyear = year

# %%
x = Student("Budi", "Darmawan", 2020)

# %%
x.printname()
# Out:
# Budi Darmawan

# %%
x.graduationyear
# Out:
# 2020

# %%
class Student(Person):
    def __init__(self, fname, lname, year):
        super().__init__(fname, lname)
        self.graduationyear = year

    def welcome(self):
        print("Hello", self.firstname, self.lastname, ", mahasiswa", self.graduationyear)

# %%
x = Student("Budi", "Darmawan", 2020)
x.welcome()
# Out:
# Hello Budi Darmawan , mahasiswa 2020

# %%
class Person:
    def __init__(self, fname, lname):
        self.firstname = fname
        self.lastname = lname

    def printname(self):
        print(self.firstname, self.lastname)

class Address:
    def __init__(self, street, city):
        self.street = street
        self.city = city
        
class Student(Person, Address):
    def __init__(self, fname, lname, street, city, year):
        Person.__init__(self, fname, lname)
        Address.__init__(self, street, city)
        self.graduationyear = year
        
    def welcome(self):
        print("Hello", self.firstname, self.lastname, ", mahasiswa", self.graduationyear)

# %%
x = Student("Budi", "Darmawan", "Jalan Sudirman No 50", "Jakarta", 2020)
x.welcome()
# Out:
# Hello Budi Darmawan , mahasiswa 2020

# %%
x.street
# Out:
# 'Jalan Sudirman No 50'

# %%
x.city
# Out:
# 'Jakarta'

# %%
def myfunc():
    x = 300
    print(x)

myfunc()

print(x)
# Out:
# 300
# <__main__.Student object at 0x0000027B522A0A40>

# %%
def myfunc():
    x = 300
    
    def myinnerfunc():
        print(x)
    myinnerfunc()

myfunc()
# Out:
# 300

# %%
x = 300

def myfunc():
    print(x)

myfunc()

print(x)
# Out:
# 300
# 300

# %%
x = 300

def myfunc():
    x = 200
    print(x)

myfunc()

def myfunc2():
    x = 700
    print(x)

myfunc2()

print(x)
# Out:
# 200
# 700
# 300

# %%
def myfunc():
    global x
    x = 300

myfunc()

print(x)
# Out:
# 300

# %%
x = 300

def myfunc():
    global x
    x = 200

myfunc()

print(x)
# Out:
# 200

# %%
import my_module

my_module.greeting("Budi")
# Out:
# Hello, Budi

# %%
from my_module import greeting

# %%
greeting("Yunus")
# Out:
# Hello, Yunus

# %%
from my_module import greeting as gt

# %%
gt("Yunus")
# Out:
# Hello, Yunus

# %%
print(dir(gt))
# Out:
# ['__annotations__', '__builtins__', '__call__', '__class__', '__closure__', '__code__', '__defaults__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__get__', '__getattribute__', '__getstate__', '__globals__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__kwdefaults__', '__le__', '__lt__', '__module__', '__name__', '__ne__', '__new__', '__qualname__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__type_params__']

# %%
import os

# %%
os.listdir()
# Out:
# ['my_module.py', 'Tugas Individu 5.ipynb', '__pycache__']

# %%
os.getcwd()
# Out:
# 'c:\\Users\\62819\\Downloads\\Tugas Individu 5'

# %%
os.mkdir("test")

# %%
os.path.exists("my_module.py")
# Out:
# True

# %%
os.path.isfile("my_module.py")
# Out:
# True

# %%
os.path.isdir("test")
# Out:
# True
